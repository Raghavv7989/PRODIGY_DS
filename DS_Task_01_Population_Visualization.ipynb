# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file_path = 'population_data.csv'  # Replace with your path
df = pd.read_csv('population_data.csv', skiprows=4)
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130075728.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2016         2017         2018         2019  \
# ...

# %%
df.columns.values[:5]
# Out:
# array(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960'], dtype=object)

# %%
df_2022 = df[['Country Name', '2022']].dropna()
df_2022['2022'] = pd.to_numeric(df_2022['2022'], errors='coerce')
df_2022 = df_2022.sort_values('2022', ascending=False)
df_2022.head()
# Out:
#             Country Name          2022
# 259                World  7.990400e+09
# 103     IDA & IBRD total  6.795050e+09
# 140  Low & middle income  6.438272e+09
# 156        Middle income  5.846791e+09
# 102            IBRD only  4.928522e+09

# %%
top10 = df_2022.head(10)
plt.figure(figsize=(12, 6))
plt.bar(top10['Country Name'], top10['2022'], color='skyblue')
plt.title('Top 10 Most Populated Countries (2022)')
plt.xlabel('Country')
plt.ylabel('Population')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df_2022['2022'], bins=20, color='lightgreen', edgecolor='black')
plt.title('Histogram of Country Populations (2022)')
plt.xlabel('Population')
plt.ylabel('Number of Countries')
plt.tight_layout()
plt.show()
